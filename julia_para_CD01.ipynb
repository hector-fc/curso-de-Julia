# %% [markdown]
# # 💻 Introdução a  Julia
# - Variáveis  e atribuição de valores
# - Tipos de variáveis
# - Inteiros
# - Numeros flutuantes
# - Booleanos
# - String
# - listas
# - tuplas
# - Dicionários
# - Conjuntos
# - Mudando o tipo de variaveis

# %% [markdown]
# ## 1 Variável    e atribuição de valores
# Variáveis são espaços na memória do seu computador. Para atribuir algum valor a uma variável usa-se a seguinte sintaxe:
#
# my_float = 3.0
#
# (variavel) (sinal de atrbuição )(valor)

# %%
my_float = 3.0
# Out:
# 3.0

# %%
😄 = 23
# Out:
# 23

# %%
😈 = -7
# Out:
# -7

# %%
😏 = 😄 + 😈
# Out:
# 16

# %%
typeof(😏)
# Out:
# Int64

# %% [markdown]
# ## 💯 Tipos de  variáveis

# %%
x =  3.0
# Out:
# 3.0

# %%
typeof(x)
# Out:
# Float64

# %%
x = "tres"
# Out:
# "tres"

# %%
typeof(x)
# Out:
# String

# %%
x = true
# Out:
# true

# %%
typeof(x)
# Out:
# Bool

# %%
x = [3,4,5]
# Out:
# 3-element Vector{Int64}:
#  3
#  4
#  5

# %%
typeof(x)
# Out:
# Vector{Int64} (alias for Array{Int64, 1})

# %%
🍌= 7
# Out:
# 7

# %%
typeof(🍌)
# Out:
# Int64

# %%
😄 = 10
# Out:
# 10

# %%
😄 + 🍌
# Out:
# 17

# %% [markdown]
# ## Inteiros

# %%
x = 3
# Out:
# 3

# %%
typeof(x)
# Out:
# Int64

# %%
y =5
# Out:
# 5

# %%
z = x - y
# Out:
# -2

# %%
typeof(z)
# Out:
# Int64

# %%
x^2
# Out:
# 9

# %% [markdown]
# x/y

# %%
x//y
# Out:
# 3//5

# %% [markdown]
# ## Operações lógicas com inteiros

# %%
# relação de ordem 
x>y
# Out:
# false

# %%
x>=y
# Out:
# false

# %%
x==y
# Out:
# false

# %% [markdown]
# ## Operações lógicas com variaveis booleanas

# %%
x =  true; y= false;

# %%
x && y
# Out:
# false

# %%
x || y
# Out:
# true

# %%
~ x
# Out:
# false

# %%
x == y
# Out:
# false

# %% [markdown]
# ## Aplicação  (checando a validade das leis de morgan)

# %%
x =  true; y = true;
!( x && y) == (! x ||  ! y)
# Out:
# true

# %%
x=  false; y = true;
!( x && y) == (! x ||  ! y)
# Out:
# true

# %%
x= false ; y = false;
!( x && y) == (! x ||  ! y)
# Out:
# true

# %% [markdown]
# # Slicing String

# %%
name = "Skywalker"
# Out:
# "Skywalker"

# %%
name[1]
# Out:
# 'S': ASCII/Unicode U+0053 (category Lu: Letter, uppercase)

# %%
name[end] ##   in python work  name[-1]
# Out:
# 'r': ASCII/Unicode U+0072 (category Ll: Letter, lowercase)

# %%
name[1:3]  ## anoter diference  with python
# Out:
# "Sky"

# %%
name[end-2:end]
# Out:
# "ker"

# %%
name[begin:2:end]
# Out:
# "Syakr"

# %%
reverse(name)
# Out:
# "reklawykS"

# %%
length(name)
# Out:
# 9

# %% [markdown]
# # Arrays

# %%
lista=  Array{Any,1}(undef,4)
# Out:
# 4-element Vector{Any}:
#  #undef
#  #undef
#  #undef
#  #undef

# %%
lista[1]= "a"
# Out:
# "a"

# %%
lista[2]= 2
# Out:
# 2

# %%
lista[3] = "fchect"
# Out:
# "fchect"

# %%
lista[4] = 2.3
# Out:
# 2.3

# %%
lista
# Out:
# 4-element Vector{Any}:
#   "a"
#  2
#   "fchect"
#  2.3

# %%
ligth = Array{String}(undef,2)
# Out:
# 2-element Vector{String}:
#  #undef
#  #undef

# %%
greek_letters = ["Eta","Mu","Psi","Tau","Phi"]
# Out:
# 5-element Vector{String}:
#  "Eta"
#  "Mu"
#  "Psi"
#  "Tau"
#  "Phi"

# %%
greek_letters[1]
# Out:
# "Eta"

# %%
greek_letters[end]
# Out:
# "Phi"

# %% [markdown]
# ## Tuples

# %%
tupl = (2,3,4,5)
# Out:
# (2, 3, 4, 5)

# %%
tupl = ((2,3,4,5),(2,3,5,6))
# Out:
# ((2, 3, 4, 5), (2, 3, 5, 6))

# %%
tupl[1]
# Out:
# (2, 3, 4, 5)

# %%
tupl[1][1]
# Out:
# 2

# %%
# tupla com string floats, bolean, inteiros etc 
tupl = (4,1.4,"quatro",'3',false,[4,"um"])
# Out:
# (4, 1.4, "quatro", '3', false, Any[4, "um"])

# %%
reverse(tupl)
# Out:
# (Any[4, "um"], false, '3', "quatro", 1.4, 4)

# %%
length(tupl)
# Out:
# 6

# %%
map(typeof,tupl)
# Out:
# (Int64, Float64, String, Char, Bool, Vector{Any})

# %%
isempty(tupl)
# Out:
# false

# %%
tupl
# Out:
# (4, 1.4, "quatro", '3', false, Any[4, "um"])

# %%
tupl[1:3]
# Out:
# (4, 1.4, "quatro")

# %% [markdown]
# ## Dicionários

# %%
numbers = Dict(
    1=>"um", 
    5=>"cinco",
    18=>"dezeoito",
    20=>"vinte" )
# Out:
# Dict{Int64, String} with 4 entries:
#   5  => "cinco"
#   20 => "vinte"
#   18 => "dezeoito"
#   1  => "um"

# %%
numbers[1]
# Out:
# "um"

# %%
numbers[20]
# Out:
# "vinte"

# %%
typeof(numbers)
# Out:
# Dict{Int64, String}

# %%
numbers
# Out:
# Dict{Int64, String} with 4 entries:
#   5  => "cinco"
#   20 => "vinte"
#   18 => "dezeoito"
#   1  => "um"

# %%
delete!(numbers,1)
# Out:
# Dict{Int64, String} with 3 entries:
#   5  => "cinco"
#   20 => "vinte"
#   18 => "dezeoito"

# %%
keys(numbers)
# Out:
# KeySet for a Dict{Int64, String} with 3 entries. Keys:
#   5
#   20
#   18

# %%
values(numbers)
# Out:
# ValueIterator for a Dict{Int64, String} with 3 entries. Values:
#   "cinco"
#   "vinte"
#   "dezeoito"

# %%
jedi = Dict("Anakin"=>"Dark",
    "Obi-Wan"=>"light",
    "Yoda"=>"light",
    "sidius"=>"dark"
    )
# Out:
# Dict{String, String} with 4 entries:
#   "sidius"  => "dark"
#   "Yoda"    => "light"
#   "Anakin"  => "Dark"
#   "Obi-Wan" => "light"

# %%
jedi["Anakin"]
# Out:
# "Dark"

# %% [markdown]
# Chaves e valores de um dicionário podem ser de qualquer tipo.

# %%
star_wars= 
Dict("movie_name"=> 
    Dict("A new hope"=> 
        Dict("year"=>1977,
            "director"=>"Geoge Luca",
            "Duration_minutes"=>121
            )        
        ),
    "Return of the Jedi"=>
        Dict("year"=>1977,
            "director"=>"Geoge Luca",
            "Duration_minutes"=>121
            ),        
    "general_description"=>"Adventures through the galaxy"
    )
# Out:
# Dict{String, Any} with 3 entries:
#   "Return of the Jedi"  => Dict{String, Any}("director"=>"Geoge Luca", "year"=>…
#   "general_description" => "Adventures through the galaxy"
#   "movie_name"          => Dict{String, Dict{String, Any}}("A new hope"=>Dict("…

# %%
keys(star_wars)
# Out:
# KeySet for a Dict{String, Any} with 3 entries. Keys:
#   "Return of the Jedi"
#   "general_description"
#   "movie_name"

# %%
keys(star_wars)
# Out:
# KeySet for a Dict{String, Any} with 3 entries. Keys:
#   "Return of the Jedi"
#   "general_description"
#   "movie_name"

# %%
star_wars["Return of the Jedi"]["director"]
# Out:
# "Geoge Luca"

# %% [markdown]
# ### Métodos em dicionários

# %%
numbers = Dict(
    1=>"um", 
    5=>"cinco",
    18=>"dezeoito",
    20=>"vinte" )
# Out:
# Dict{Int64, String} with 4 entries:
#   5  => "cinco"
#   20 => "vinte"
#   18 => "dezeoito"
#   1  => "um"

# %%
delete!(numbers,1)
# Out:
# Dict{Int64, String} with 3 entries:
#   5  => "cinco"
#   20 => "vinte"
#   18 => "dezeoito"

# %%
numbers
# Out:
# Dict{Int64, String} with 3 entries:
#   5  => "cinco"
#   20 => "vinte"
#   18 => "dezeoito"

# %% [markdown]
# ## Conjuntos
# https://www.geeksforgeeks.org/sets-in-julia/

# %%
set1 = Set()
# Out:
# Set{Any}()

# %%
typeof(set1)
# Out:
# Set{Any}

# %%
set2 = Set([1,2,3,4,5])
# Out:
# Set{Int64} with 5 elements:
#   5
#   4
#   2
#   3
#   1

# %%
set3 =Set([1,2,3,"dark","side"])
# Out:
# Set{Any} with 5 elements:
#   2
#   "side"
#   "dark"
#   3
#   1

# %%
"dark" in set3
# Out:
# true

# %%
union(set1,set3)
# Out:
# Set{Any} with 5 elements:
#   2
#   "side"
#   "dark"
#   3
#   1

# %%
intersect!(set1,set3)
# Out:
# Set{Any}()

# %%
set4= Set([2,3,"light","side"])
# Out:
# Set{Any} with 4 elements:
#   2
#   "side"
#   "light"
#   3

# %%
intersect!(set4,set3)
# Out:
# Set{Any} with 3 elements:
#   2
#   "side"
#   3

# %%
setdiff(set4,set2)
# Out:
# Set{Any} with 1 element:
#   "side"

# %%
set3
# Out:
# Set{Any} with 5 elements:
#   2
#   "side"
#   "dark"
#   3
#   1

# %%
delete!(set3,1)
# Out:
# Set{Any} with 4 elements:
#   2
#   "side"
#   "dark"
#   3

# %%
set4
# Out:
# Set{Any} with 3 elements:
#   2
#   "side"
#   3

# %% [markdown]
# ## Mudando o tipo de das variáveis

# %%
x =  trunc(Int,1.2)
# Out:
# 1

# %%
typeof(x)
# Out:
# Int64

# %%
typeof(1.2)
# Out:
# Float64

# %%
y  = floor(1.2)
# Out:
# 1.0

# %% [markdown]
# ## Built  in  Function

# %%
println("Ola mundo")
# Out:
# Ola mundo

# %%
array = [1,7,1,4,5]
# Out:
# 5-element Vector{Int64}:
#  1
#  7
#  1
#  4
#  5

# %%
maximum(array)
# Out:
# 7

# %%
# encontrando a chave de valor máximo em um dicionário
my_dict = Dict('a'=> 51, 'b'=> 31, 'c'=> 20)
values(my_dict)
# Out:
# ValueIterator for a Dict{Char, Int64} with 3 entries. Values:
#   51
#   20
#   31

# %%
tupl = (2,3,2,5,7,8)
# Out:
# (2, 3, 2, 5, 7, 8)

# %%
maximum(tupl)
# Out:
# 8

# %%
maximum(values(my_dict))
# Out:
# 51

# %%
array
# Out:
# 5-element Vector{Int64}:
#  1
#  7
#  1
#  4
#  5

# %%
sort(array)
# Out:
# 5-element Vector{Int64}:
#  1
#  1
#  4
#  5
#  7

# %%
?parse
# Out:
# search: parse tryparse partialsortperm partialsortperm! pairs skipchars
#   parse(type, str; base)
#
#   Parse a string as a number. For Integer types, a base can be specified (the
#   default is 10). For floating-point types, the string is parsed as a decimal
#   floating-point number. Complex types are parsed from decimal strings of the
#   form "R±Iim" as a Complex(R,I) of the requested type; "i" or "j" can also be
#   used instead of "im", and "R" or "Iim" are also permitted. If the string
#   does not contain a valid number, an error is raised.
#
#   │ Julia 1.1
#   │
#   │  parse(Bool, str) requires at least Julia 1.1.
#
#   Examples
#   ≡≡≡≡≡≡≡≡≡≡
#
#   julia> parse(Int, "1234")
#   1234
#
#   julia> parse(Int, "1234", base = 5)
#   194
#
#   julia> parse(Int, "afc", base = 16)
#   2812
#
#   julia> parse(Float64, "1.2e-3")
#   0.0012
#
#   julia> parse(Complex{Float64}, "3.2e-1 + 4.5im")
#   0.32 + 4.5im
#
# ...
